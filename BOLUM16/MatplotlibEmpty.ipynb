# %% [markdown]
# ### Kütüphaneyi projeye dahil etmek

# %% [markdown]
# ## Bir grafik yaratmak
#
#
# *   pyplot() yöntemi
# *   OO yöntemi

# %% [markdown]
# ### Pyplot yöntemi

# %%
# plt.plot()

# %%
# Noktalı Virgül ile
# plt.plot();

# %%
# plt.show()

# %%
# Biraz veri ile deneme
# plt.plot(x, y);

# %% [markdown]
# ### OO yöntemi

# %%
# OO yöntemi

# %%
# figure plot

# %%
# Bir grafik oluşturma akışı

# %% [markdown]
# ### En çok kullanılan grafik türleri
# - `line`
# - `scatter`
# - `bar`
# - `hist`
# - `subplots()`

# %% [markdown]
# #### Line

# %%
# Bir Dizi Üret

# %%
# Line Grafik

# %% [markdown]
# #### Scatter

# %%
# scatter

# %% [markdown]
# #### Bar
# * Vertical
# * Horizontal

# %%
# Bir Sözlükten Dizi Üretmek

# %% [markdown]
# #### Histogram (hist)

# %%
# histogram

# %% [markdown]
# #### Subplots

# %%
# Subplots

# %% [markdown]
# #### Pandas üzerinden grafik çizmek

# %% [markdown]
# ### Line
# * Concept
# * DataFrame

# %% [markdown]
# #### Mevcut veri ile çalışmak

# %% [markdown]
# #### Bar
# * Concept
# * DataFrame

# %% [markdown]
# #### Histogramlar

# %%
# bins  10

# %% [markdown]
# #### Başka bir datasetle deneyelim

# %% [markdown]
# #### Subplots
# * Concept
# * DataFrame

# %% [markdown]
# #### Pandas ile OO metodunu kullanmak

# %% [markdown]
# ## Grafiklerinizi değiştirin
#
# * `limits (xlim, ylim)`, `colors`, `styles`, `legends`

# %% [markdown]
# #### Stil

# %% [markdown]
# #### title,legend ve axes değiştirme

# %% [markdown]
# ### cmap değiştirme

# %% [markdown]
# #### xlim & ylim değiştirme

# %% [markdown]
# ## Grafikleri kaydetmek

# %% [markdown]
# ### Örnek Fonksiyon
